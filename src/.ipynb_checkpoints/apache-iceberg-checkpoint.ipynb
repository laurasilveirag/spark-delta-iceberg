# %% [markdown]
# # Apache Iceberg com PySpark
# Demonstração de operações CRUD em tabelas Iceberg usando dados de E-commerce.

# %%
from pyspark.sql import SparkSession
from commons import get_raw_data, filter_southern_region

spark = SparkSession.builder.appName("IcebergLab") \
    .config("spark.jars.packages", "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.4.2") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.local", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.local.type", "hadoop") \
    .config("spark.sql.catalog.local.warehouse", "../data/iceberg") \
    .getOrCreate()

print('Spark com Iceberg iniciado com sucesso!')
# Out:
# 26/04/28 20:22:32 WARN Utils: Your hostname, NOTE-LAURA resolves to a loopback address: 127.0.1.1; using 172.17.40.94 instead (on interface eth0)
# 26/04/28 20:22:32 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/lauras/.cache/pypoetry/virtualenvs/spark-delta-iceberg-Qz15G4zY-py3.12/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/lauras/.ivy2/cache
# The jars for the packages stored in: /home/lauras/.ivy2/jars
# org.apache.iceberg#iceberg-spark-runtime-3.5_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-96e6aa0f-ebb0-464b-a7dd-0281e83435b4;1.0
# 	confs: [default]
# 	found org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.4.2 in central
# :: resolution report :: resolve 8283ms :: artifacts dl 6ms
# 	:: modules in use:
# 	org.apache.iceberg#iceberg-spark-runtime-3.5_2.12;1.4.2 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   1   |   0   |   0   |   0   ||   1   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-96e6aa0f-ebb0-464b-a7dd-0281e83435b4
# 	confs: [default]
# 	0 artifacts copied, 1 already retrieved (0kB/6ms)
# 26/04/28 20:22:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/28 20:22:35 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Spark com Iceberg iniciado com sucesso!

# %% [markdown]
# ## Carregando os dados

# %%
df_vendas = get_raw_data(spark, "vendas.csv")
df_clientes = get_raw_data(spark, "clientes.csv")
df_vendas.show(20)
df_clientes.show(20)
# Out:
# +--------+----------+----------+------+-----------+
# |id_venda|id_cliente|data_venda| valor|     status|
# +--------+----------+----------+------+-----------+
# |       1|       101|2023-01-15| 250.5|  concluido|
# |       2|       102|2023-01-16| 120.0|  concluido|
# |       3|       103|2023-01-17| 340.9|  cancelado|
# |       4|       101|2023-01-18|  50.0|  concluido|
# |       5|       104|2023-01-19|1500.0|  concluido|
# |       6|       105|2023-01-20|  89.9|  concluido|
# |       7|       106|2023-01-21| 450.0|   pendente|
# |       8|       107|2023-01-22|1200.5|  concluido|
# |       9|       108|2023-01-23|299.99|  concluido|
# |      10|       109|2023-01-24|  75.0|  cancelado|
# |      11|       110|2023-01-25| 600.0|  concluido|
# |      12|       111|2023-01-26| 315.2|  concluido|
# |      13|       112|2023-01-27| 140.0|processando|
# |      14|       113|2023-01-28| 980.0|  concluido|
# |      15|       114|2023-01-29|  55.5|  concluido|
# |      16|       104|2023-01-30| 210.0|  concluido|
# +--------+----------+----------+------+-----------+
#
# +----------+---------------+------+
# |id_cliente|           nome|estado|
# +----------+---------------+------+
# |       101|      Ana Julia|    SC|
# |       102| Laura Silveira|    RS|
# |       103|      Joaozinho|    SP|
# |       104|        Janaina|    PR|
# |       105| Carlos Eduardo|    MG|
# |       106| Maria Fernanda|    RJ|
# |       107| Pedro Henrique|    BA|
# |       108|  Beatriz Souza|    AM|
# |       109|   Rafael Costa|    MT|
# |       110|   Camila Rocha|    SC|
# |       111|  Lucas Almeida|    RS|
# |       112|   Juliana Lima|    CE|
# |       113|Marcos Vinicius|    GO|
# |       114|Leticia Ribeiro|    PE|
# +----------+---------------+------+

# %% [markdown]
# ## INSERT — Salvando dados no formato Iceberg

# %%
df_sul = filter_southern_region(df_vendas.join(df_clientes, "id_cliente"))
df_sul.write.format("iceberg").mode("overwrite").saveAsTable("local.vendas_sul")
print('Dados salvos no Iceberg!')
spark.sql("SELECT * FROM local.vendas_sul").show()
# Out:
# Dados salvos no Iceberg!
# +----------+--------+----------+------+---------+--------------+------+
# |id_cliente|id_venda|data_venda| valor|   status|          nome|estado|
# +----------+--------+----------+------+---------+--------------+------+
# |       101|       1|2023-01-15| 250.5|concluido|     Ana Julia|    SC|
# |       102|       2|2023-01-16| 120.0|concluido|Laura Silveira|    RS|
# |       101|       4|2023-01-18|  50.0|concluido|     Ana Julia|    SC|
# |       104|       5|2023-01-19|1500.0|concluido|       Janaina|    PR|
# |       110|      11|2023-01-25| 600.0|concluido|  Camila Rocha|    SC|
# |       111|      12|2023-01-26| 315.2|concluido| Lucas Almeida|    RS|
# |       104|      16|2023-01-30| 210.0|concluido|       Janaina|    PR|
# +----------+--------+----------+------+---------+--------------+------+

# %% [markdown]
# ## UPDATE — Atualizando status de uma venda

# %%
spark.sql("UPDATE local.vendas_sul SET valor = valor * 1.10 WHERE id_venda = 1")

print('UPDATE realizado com sucesso no Iceberg!')
spark.sql("SELECT * FROM local.vendas_sul ORDER BY id_venda").show()
# Out:
# UPDATE realizado!
# +----------+--------+----------+------+---------+--------------+------+
# |id_cliente|id_venda|data_venda| valor|   status|          nome|estado|
# +----------+--------+----------+------+---------+--------------+------+
# |       101|       1|2023-01-15| 250.5|concluido|     Ana Julia|    SC|
# |       102|       2|2023-01-16| 120.0|concluido|Laura Silveira|    RS|
# |       101|       4|2023-01-18|  50.0|concluido|     Ana Julia|    SC|
# |       104|       5|2023-01-19|1500.0|devolvido|       Janaina|    PR|
# |       110|      11|2023-01-25| 600.0|concluido|  Camila Rocha|    SC|
# |       111|      12|2023-01-26| 315.2|concluido| Lucas Almeida|    RS|
# |       104|      16|2023-01-30| 210.0|concluido|       Janaina|    PR|
# +----------+--------+----------+------+---------+--------------+------+

# %% [markdown]
# ## DELETE — Removendo uma venda

# %%
spark.sql("DELETE FROM local.vendas_sul WHERE id_venda = 4")
print('DELETE realizado!')
spark.sql("SELECT * FROM local.vendas_sul").show()
# Out:
# DELETE realizado!
# +----------+--------+----------+------+---------+--------------+------+
# |id_cliente|id_venda|data_venda| valor|   status|          nome|estado|
# +----------+--------+----------+------+---------+--------------+------+
# |       101|       1|2023-01-15| 250.5|concluido|     Ana Julia|    SC|
# |       102|       2|2023-01-16| 120.0|concluido|Laura Silveira|    RS|
# |       104|       5|2023-01-19|1500.0|devolvido|       Janaina|    PR|
# |       110|      11|2023-01-25| 600.0|concluido|  Camila Rocha|    SC|
# |       111|      12|2023-01-26| 315.2|concluido| Lucas Almeida|    RS|
# |       104|      16|2023-01-30| 210.0|concluido|       Janaina|    PR|
# +----------+--------+----------+------+---------+--------------+------+
